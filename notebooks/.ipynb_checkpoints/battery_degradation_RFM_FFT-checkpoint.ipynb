# %%
import pandas as pd
import matplotlib.pyplot as plt
import keras
import numpy as np
import os
import seaborn as sns


from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_percentage_error

from sklearn.model_selection import  train_test_split
from sklearn.model_selection import GridSearchCV

import pickle

import gzip


os.chdir('../')
from functions.model_wrapper import Tree_Model, rfm_params, get_y_w_threshold


# These are batteries that show anomalies in the measnurements, and are therefore excluded.
excl_filenames = ['2018-04-12_batch8_CH46', '2017-06-30_3_6C-30per_6C_CH15', '2017-06-30_2C-7per_5_5C_CH12',
                  '2018-04-12_batch8_CH46', '2017-06-30_6C-60per_3C_CH48']

# %%
with gzip.open('data/filtered_data_frames.pckl', 'rb') as f:
    data_frames = pickle.load(f)

# %% [markdown]
# # Recreate the data grid

# %%
first100rows_data_frames = [data_frame.iloc[: 100, :] for data_frame in data_frames]
X_all = pd.concat(first100rows_data_frames, axis = 0)
X_all = X_all[[col for col in X_all.columns if col not in excl_filenames]]
X_all = X_all.T

# %%
with gzip.open('data/CC_data_frames_FFT.pckl', 'rb') as f:
    CC_data_frames_FFT = pickle.load(f)
df_FF_peaks = pd.concat(CC_data_frames_FFT)
X_all = pd.merge(X_all, df_FF_peaks, left_index=True, right_index=True)

# %%
with gzip.open('data/CV_data_frames_FFT.pckl', 'rb') as f:
    CV_data_frames_FFT = pickle.load(f)
df_FF_peaks = pd.concat(CV_data_frames_FFT)

X_all = pd.merge(X_all, df_FF_peaks, left_index=True, right_index=True)

# %%
X_all.fillna(0, inplace = True)

# %% [markdown]
# # Convert schedule_version to categoric variable.

# %%
X_all["schedule_version"] = X_all["schedule_version"] == '7.00.08'

# %%
X_CC = data_frames[0]
X_CC = X_CC[[col for col in X_CC.columns if col not in excl_filenames]]

# get y which is number of cycle it dropped below threshold
threshold = 0.9
y_all = get_y_w_threshold(X_CC, threshold)

# %% [markdown]
# # Create Grid Search parameters

# %%
parameters = {'max_depth' : [250, 500, 1000],
              'max_features' : [0.7, 0.6, 0.5, 'sqrt', 'log2'],
             }
# I reduced the number of estimators and n_jobs for grid search
rfm_params = {'n_estimators': 80,
 # 'max_features': 0.5,
 # 'max_depth': 300,
 'bootstrap': True,
 'criterion': 'squared_error',
 'verbose': 1,
 'oob_score': True,
 'n_jobs': 8}

rfm_params["n_estimators"] = 40
rfm_params["n_jobs"] = 2
rfm_params["verbose"] = 0

# %% [markdown]
# # Grid search w RMS error as metric

# %%
rfm = RandomForestRegressor(random_state = 1)
rfm.set_params(**rfm_params)
clf_rmse = GridSearchCV(rfm, parameters, scoring = 'neg_root_mean_squared_error', cv = 6)
clf_rmse.fit(X_all, y_all.values)

plt.title("Grid search for Max Depth and Max Features:  Metric = RMS error")
xlabels = [x for x in map(str, clf_rmse.cv_results_["params"])]
plt.bar(xlabels, 
        height = -clf_rmse.cv_results_["mean_test_score"],
        yerr=clf_rmse.cv_results_["std_test_score"],
        color = ['blue'],
        edgecolor = ['grey'],
        linewidth = 6
       )
plt.ylabel("rms error (predicted cycles)")
plt.xticks(rotation = 45, horizontalalignment="right")
plt.ylim(-clf_rmse.cv_results_["mean_test_score"].max()*0.6, -clf_rmse.cv_results_["mean_test_score"].min()*1.3)
plt.grid(linestyle = "--")
plt.show()
# Out:
# /Users/willtong/Library/Caches/pypoetry/virtualenvs/wine-libraries-e_IOXrlx-py3.12/lib/python3.12/site-packages/numpy/ma/core.py:2846: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# # Grid search w R^2 as metric

# %%
# Use R^2 as a metric for grid search
clf_r2 = GridSearchCV(rfm, parameters, scoring = 'r2', cv = 6)
clf_r2.fit(X_all, y_all.values)
plt.title("Grid search for Max Depth and Max Features:  Metric = R^2")
plt.bar(xlabels, 
        clf_r2.cv_results_["mean_test_score"], 
        yerr=clf_r2.cv_results_["std_test_score"]/10,
        color = ['r'],
        edgecolor = ['grey'],
        linewidth = 6
       )
plt.ylabel(clf_r2.scoring)
plt.xticks(rotation = 45, horizontalalignment="right")
# plt.ylim(clf_r2.cv_results_["mean_test_score"].min()*0.95, clf_r2.cv_results_["mean_test_score"].max()*1.05)
plt.grid(linestyle = "--")
plt.show()

# %% [markdown]
# # Best parameters: are max_depth = 250, max_features = 0.6

# %%
rfm_params["n_estimators"] = 100000
rfm_params["n_jobs"] = 6
rfm_params["max_depth"] = 250
rfm_params["max_features"] = 'sqrt'
rfm_params["verbose"] = 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X_all, y_all, 
                                                    train_size=0.8, test_size=0.2, 
                                                    random_state=120)

# %%
rfm = Tree_Model(Model = RandomForestRegressor,
                 params = rfm_params,
                 cycle_max=3000
                 )

rfm.fit(X_train, y_train)
y_test_pred = rfm.predict(X_test, y_test)
# Out:
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=6)]: Done 4038 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=6)]: Done 4988 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=6)]: Done 6038 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=6)]: Done 7188 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=6)]: Done 8438 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=6)]: Done 9788 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=6)]: Done 11238 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=6)]: Done 12788 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=6)]: Done 14438 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=6)]: Done 16188 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=6)]: Done 18038 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=6)]: Done 19988 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=6)]: Done 22038 tasks      | elapsed:    6.9s
# [Parallel(n_jobs=6)]: Done 24188 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=6)]: Done 26438 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=6)]: Done 28788 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=6)]: Done 31238 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=6)]: Done 33788 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=6)]: Done 36438 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=6)]: Done 39188 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=6)]: Done 42038 tasks      | elapsed:   13.4s
# [Parallel(n_jobs=6)]: Done 44988 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=6)]: Done 48038 tasks      | elapsed:   15.3s
# [Parallel(n_jobs=6)]: Done 51188 tasks      | elapsed:   16.3s
# [Parallel(n_jobs=6)]: Done 54438 tasks      | elapsed:   17.3s
# [Parallel(n_jobs=6)]: Done 57788 tasks      | elapsed:   18.4s
# [Parallel(n_jobs=6)]: Done 61238 tasks      | elapsed:   19.5s
# [Parallel(n_jobs=6)]: Done 64788 tasks      | elapsed:   20.7s
# [Parallel(n_jobs=6)]: Done 68438 tasks      | elapsed:   21.9s
# [Parallel(n_jobs=6)]: Done 72188 tasks      | elapsed:   23.1s
# [Parallel(n_jobs=6)]: Done 76038 tasks      | elapsed:   24.3s
# [Parallel(n_jobs=6)]: Done 79988 tasks      | elapsed:   25.6s
# [Parallel(n_jobs=6)]: Done 84038 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=6)]: Done 88188 tasks      | elapsed:   28.2s
# [Parallel(n_jobs=6)]: Done 92438 tasks      | elapsed:   29.6s
# [Parallel(n_jobs=6)]: Done 96788 tasks      | elapsed:   31.0s
# [Parallel(n_jobs=6)]: Done 100000 out of 100000 | elapsed:   32.0s finished
# Finished fitting.  Predicting X...
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 4038 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 4988 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 6038 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 7188 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done 8438 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done 9788 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 11238 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 12788 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done 14438 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done 16188 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done 18038 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done 19988 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done 22038 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done 24188 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done 26438 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=6)]: Done 28788 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done 31238 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=6)]: Done 33788 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=6)]: Done 36438 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=6)]: Done 39188 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=6)]: Done 42038 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=6)]: Done 44988 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=6)]: Done 48038 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=6)]: Done 51188 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=6)]: Done 54438 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=6)]: Done 57788 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=6)]: Done 61238 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=6)]: Done 64788 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=6)]: Done 68438 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=6)]: Done 72188 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=6)]: Done 76038 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=6)]: Done 79988 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=6)]: Done 84038 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=6)]: Done 88188 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=6)]: Done 92438 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=6)]: Done 96788 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=6)]: Done 100000 out of 100000 | elapsed:    3.8s finished
# Finished predicting X.
# Training MdAPE is 4.434920054200536% (not holdout).
# Finished training mdoel
# MdAPE is 4.434920054200536%
# R2: 0.939, RMSE: 79.368, MAE: 48.901
# Plotting scatter plot...
# [Parallel(n_jobs=6)]: Using backend ThreadingBackend with 6 concurrent workers.
# [Parallel(n_jobs=6)]: Done  38 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 188 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 438 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 788 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 1238 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=6)]: Done 1788 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 2438 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 3188 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 4038 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=6)]: Done 4988 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 6038 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 7188 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=6)]: Done 8438 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done 9788 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=6)]: Done 11238 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 12788 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=6)]: Done 14438 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done 16188 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=6)]: Done 18038 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=6)]: Done 19988 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done 22038 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=6)]: Done 24188 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=6)]: Done 26438 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done 28788 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=6)]: Done 31238 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=6)]: Done 33788 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=6)]: Done 36438 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=6)]: Done 39188 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=6)]: Done 42038 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=6)]: Done 44988 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=6)]: Done 48038 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=6)]: Done 51188 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=6)]: Done 54438 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=6)]: Done 57788 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=6)]: Done 61238 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=6)]: Done 64788 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=6)]: Done 68438 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=6)]: Done 72188 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=6)]: Done 76038 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=6)]: Done 79988 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=6)]: Done 84038 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=6)]: Done 88188 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=6)]: Done 92438 tasks      | elapsed:    2.8s
# MdAPE is 8.021602564102558%
# R2: 0.653, RMSE: 190.932, MAE: 124.052
# Plotting scatter plot...
# [Parallel(n_jobs=6)]: Done 96788 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=6)]: Done 100000 out of 100000 | elapsed:    3.0s finished

# %% [markdown]
# # From above, the HOLDOUT MdAPE = 8.03, R^2 = 0.705

# %%
with gzip.open('data/gzipX_FFT.pckl', 'wb') as f:
    pickle.dump(X_all, f)

with gzip.open('data/gzipy_FFT.pckl', 'wb') as f:
    pickle.dump(y_all, f)

with open('data/rfm_model_1e6_FFT.pckl', 'wb') as f:
    pickle.dump(rfm, f)

# %%
data_points =[x[0] for x in rfm.feature_imp]
importances =[x[1] for x in rfm.feature_imp]
plt.figure(figsize=(120,12))
plt.scatter(data_points, importances)
plt.xticks(rotation = 35, horizontalalignment = 'right')
plt.grid()
plt.savefig('figures/feature_imp.png')
plt.show()

# %%
importances_sums = {}
for feature_imp in rfm.feature_imp:
    category = feature_imp[0].split('_')[-1]
    if category in importances_sums.keys():
        importances_sums[category] += feature_imp[1]
    else:
        importances_sums[category] = feature_imp[1] 

import_sums = [(key, importances_sums[key]) for key in importances_sums.keys()]

import_sums = sorted(import_sums, key=lambda x: x[1], reverse = True)
str([(x[0], float(np.round(x[1], 5))) for x in import_sums])
# Out:
# "[('CycleTime', 0.4325), ('Capacity', 0.1903), ('Resistance', 0.15724), ('Temperature', 0.08649), ('CCArea', 0.0661), ('CVArea', 0.06217), ('maxfreqCV', 0.00248), ('maxfreqCC', 0.00239), ('version', 0.00034)]"

# %% [markdown]
# # Feature importances

# %%
feature_imp = sorted(rfm.feature_imp, key = lambda x: x[1], reverse = True)
with open('data/feature_importances_rfm1e6_FFT.pckl', 'wb') as f:
    pickle.dump(feature_imp,  f)      
feature_imp
# Out:
# [('07_harmonic_CVArea', np.float64(0.01961684721671533)),
#  ('07_harmonic_CCArea', np.float64(0.013285592898576509)),
#  ('08_harmonic_CCArea', np.float64(0.011732544589712943)),
#  ('06_harmonic_CCArea', np.float64(0.009174211062796677)),
#  ('00_harmonic_CCArea', np.float64(0.007697722322555578)),
#  ('05_harmonic_CVArea', np.float64(0.006811494341907332)),
#  ('09_harmonic_CVArea', np.float64(0.00648715075355717)),
#  ('04_harmonic_CVArea', np.float64(0.0058804312343286695)),
#  ('04_harmonic_CCArea', np.float64(0.005865521999669475)),
#  ('4_Charge_Capacity', np.float64(0.005797028897336558)),
#  ('08_harmonic_CVArea', np.float64(0.005311048446541533)),
#  ('10_CycleTime', np.float64(0.005182031725930362)),
#  ('00_harmonic_CVArea', np.float64(0.005103304099498659)),
#  ('41_CycleTime', np.float64(0.005092220047878742)),
#  ('5_CycleTime', np.float64(0.005081011140118816)),
#  ('4_CycleTime', np.float64(0.004989024628310068)),
#  ('09_harmonic_CCArea', np.float64(0.004940255712700316)),
#  ('05_harmonic_CCArea', np.float64(0.004898387172361102)),
#  ('72_CycleTime', np.float64(0.004888133542226674)),
#  ('14_Charge_Capacity', np.float64(0.0048800576388287826)),
#  ('42_CycleTime', np.float64(0.004864234550747854)),
#  ('15_CycleTime', np.float64(0.004846891106458519)),
#  ('8_CycleTime', np.float64(0.004781059052296704)),
#  ('18_Charge_Capacity', np.float64(0.004775183944654567)),
#  ('16_CycleTime', np.float64(0.004733261845786102)),
#  ('06_harmonic_CVArea', np.float64(0.004732621915567651)),
#  ('17_CycleTime', np.float64(0.0047158792387302926)),
#  ('9_CycleTime', np.float64(0.004687276047245989)),
#  ('70_CycleTime', np.float64(0.004613418918800614)),
#  ('14_CycleTime', np.float64(0.004592689802345103)),
#  ('69_CycleTime', np.float64(0.0045920874645075304)),
#  ('79_CycleTime', np.float64(0.004590999909916007)),
#  ('78_CycleTime', np.float64(0.004584952443903289)),
#  ('19_CycleTime', np.float64(0.004575438967898732)),
#  ('75_CycleTime', np.float64(0.004540241314773684)),
#  ('6_CycleTime', np.float64(0.004536165074917088)),
#  ('21_CycleTime', np.float64(0.004534742775140732)),
#  ('12_CycleTime', np.float64(0.004534687251706574)),
#  ('22_CycleTime', np.float64(0.004525695811743087)),
#  ('38_CycleTime', np.float64(0.00451551671137208)),
#  ('11_CycleTime', np.float64(0.004513096957548886)),
#  ('23_CycleTime', np.float64(0.004491167286455489)),
#  ('50_CycleTime', np.float64(0.004489490118361231)),
#  ('93_CycleTime', np.float64(0.004459142914615041)),
#  ('36_CycleTime', np.float64(0.0044418197368508985)),
#  ('44_CycleTime', np.float64(0.004440694502167796)),
#  ('58_CycleTime', np.float64(0.004423929765891768)),
#  ('24_CycleTime', np.float64(0.004420296261891848)),
#  ('59_CycleTime', np.float64(0.00441922189446661)),
#  ('18_CycleTime', np.float64(0.004397942192113894)),
#  ('20_CycleTime', np.float64(0.004384433948245332)),
#  ('62_CycleTime', np.float64(0.004381074040496351)),
#  ('46_CycleTime', np.float64(0.004373855224104769)),
#  ('73_CycleTime', np.float64(0.004373263841315487)),
#  ('60_CycleTime', np.float64(0.004366706359434744)),
#  ('101_CycleTime', np.float64(0.004360647941427975)),
#  ('76_CycleTime', np.float64(0.004359583193205222)),
#  ('64_CycleTime', np.float64(0.004358694688149605)),
#  ('95_CycleTime', np.float64(0.004356244391409458)),
#  ('98_CycleTime', np.float64(0.0043489353378728165)),
#  ('7_CycleTime', np.float64(0.004346113312881493)),
#  ('33_CycleTime', np.float64(0.004345671080357877)),
#  ('68_CycleTime', np.float64(0.004341201892050821)),
#  ('92_CycleTime', np.float64(0.004340806760858278)),
#  ('89_CycleTime', np.float64(0.004339803670118384)),
#  ('57_CycleTime', np.float64(0.004320564345447334)),
#  ('87_CycleTime', np.float64(0.00428992359309859)),
#  ('65_CycleTime', np.float64(0.004282017369234367)),
#  ('47_CycleTime', np.float64(0.00427861834211142)),
#  ('26_CycleTime', np.float64(0.0042705013027330456)),
#  ('32_CycleTime', np.float64(0.004262720160992354)),
#  ('77_CycleTime', np.float64(0.004261279124743137)),
#  ('96_CycleTime', np.float64(0.004254961600719048)),
#  ('88_CycleTime', np.float64(0.0042490868108254485)),
#  ('39_CycleTime', np.float64(0.004241841460324399)),
#  ('81_CycleTime', np.float64(0.004241492449289628)),
#  ('102_CycleTime', np.float64(0.004240593980018441)),
#  ('94_CycleTime', np.float64(0.004237455013196447)),
#  ('67_CycleTime', np.float64(0.0042363943850278205)),
#  ('91_CycleTime', np.float64(0.00423135342590707)),
#  ('61_CycleTime', np.float64(0.00422771525467876)),
#  ('48_CycleTime', np.float64(0.004220240555379288)),
#  ('103_CycleTime', np.float64(0.004211860435420244)),
#  ('35_CycleTime', np.float64(0.004199019972459932)),
#  ('100_CycleTime', np.float64(0.00419822590173961)),
#  ('49_CycleTime', np.float64(0.004191598480954869)),
#  ('90_CycleTime', np.float64(0.004184174198628081)),
#  ('98_Internal_Resistance', np.float64(0.004178741132577386)),
#  ('37_CycleTime', np.float64(0.004171761749695251)),
#  ('40_CycleTime', np.float64(0.004139589659151229)),
#  ('74_CycleTime', np.float64(0.004139318351414104)),
#  ('29_CycleTime', np.float64(0.004131884504385037)),
#  ('25_CycleTime', np.float64(0.004129624478715985)),
#  ('53_CycleTime', np.float64(0.004127952181303208)),
#  ('86_CycleTime', np.float64(0.004119045689020095)),
#  ('43_CycleTime', np.float64(0.0041172473279064824)),
#  ('16_Charge_Capacity', np.float64(0.004101264778090865)),
#  ('13_CycleTime', np.float64(0.004096459890811641)),
#  ('56_CycleTime', np.float64(0.004094702943392825)),
#  ('82_CycleTime', np.float64(0.004094243178204301)),
#  ('54_CycleTime', np.float64(0.004088214013810494)),
#  ('84_CycleTime', np.float64(0.004080002121990122)),
#  ('66_CycleTime', np.float64(0.004072986574901724)),
#  ('99_CycleTime', np.float64(0.004063503664176683)),
#  ('52_CycleTime', np.float64(0.00405746701814881)),
#  ('97_CycleTime', np.float64(0.004057144979862141)),
#  ('34_CycleTime', np.float64(0.004036818506192927)),
#  ('85_CycleTime', np.float64(0.004036067254905156)),
#  ('71_CycleTime', np.float64(0.004032677124526341)),
#  ('55_CycleTime', np.float64(0.003970582005503872)),
#  ('80_CycleTime', np.float64(0.003963283809551601)),
#  ('63_CycleTime', np.float64(0.0039629779653354655)),
#  ('28_CycleTime', np.float64(0.003961018840758212)),
#  ('51_CycleTime', np.float64(0.003958734706959549)),
#  ('27_CycleTime', np.float64(0.00390311700034032)),
#  ('83_CycleTime', np.float64(0.0038400788504780793)),
#  ('45_CycleTime', np.float64(0.0038030774084688848)),
#  ('30_CycleTime', np.float64(0.0037592129529069405)),
#  ('03_harmonic_CCArea', np.float64(0.0037065884181550343)),
#  ('31_CycleTime', np.float64(0.0036863046590418828)),
#  ('5_Charge_Capacity', np.float64(0.00367836503071152)),
#  ('6_Charge_Capacity', np.float64(0.0036000482720686534)),
#  ('11_Charge_Capacity', np.float64(0.003435450513320063)),
#  ('97_Internal_Resistance', np.float64(0.003367251775911601)),
#  ('13_Charge_Capacity', np.float64(0.0033422464461956556)),
#  ('02_harmonic_CVArea', np.float64(0.003325220575086413)),
#  ('96_Internal_Resistance', np.float64(0.0033161606996491995)),
#  ('57_Charge_Capacity', np.float64(0.003284375686631358)),
#  ('15_Charge_Capacity', np.float64(0.0032697674862398633)),
#  ('94_Internal_Resistance', np.float64(0.003226223258923172)),
#  ('44_Charge_Capacity', np.float64(0.0030215460075852033)),
#  ('98_Charge_Capacity', np.float64(0.0029799625601410144)),
#  ('100_Internal_Resistance', np.float64(0.002970540457093127)),
#  ('99_Internal_Resistance', np.float64(0.0029407352517993087)),
#  ('3_Charge_Capacity', np.float64(0.0028624001071607084)),
#  ('37_Charge_Capacity', np.float64(0.0028495625269703124)),
#  ('95_Internal_Resistance', np.float64(0.0028404809606952176)),
#  ('4_Internal_Resistance', np.float64(0.0028389081443397552)),
#  ('30_Charge_Capacity', np.float64(0.002838308091003041)),
#  ('97_Charge_Capacity', np.float64(0.0027687959797132087)),
#  ('103_Internal_Resistance', np.float64(0.0027632246807076403)),
#  ('87_Charge_Capacity', np.float64(0.0025335012525235004)),
#  ('96_Charge_Capacity', np.float64(0.002512693102791584)),
#  ('91_Internal_Resistance', np.float64(0.0025077211391755084)),
#  ('01_harmonic_CVArea', np.float64(0.0024960299723113593)),
#  ('maxfreqCV', np.float64(0.0024764208750398353)),
#  ('102_Internal_Resistance', np.float64(0.0024752141267359866)),
#  ('90_Charge_Capacity', np.float64(0.0024582867726582226)),
#  ('92_Internal_Resistance', np.float64(0.0024425271259848743)),
#  ('5_Internal_Resistance', np.float64(0.0024163886295037428)),
#  ('01_harmonic_CCArea', np.float64(0.0024068311784523192)),
#  ('03_harmonic_CVArea', np.float64(0.0024052996103862503)),
#  ('02_harmonic_CCArea', np.float64(0.0023878937919114985)),
#  ('maxfreqCC', np.float64(0.002387460916032863)),
#  ('52_Charge_Capacity', np.float64(0.002374470837704644)),
#  ('92_Charge_Capacity', np.float64(0.0023726366105239383)),
#  ('93_Internal_Resistance', np.float64(0.0023586179926157282)),
#  ('58_Charge_Capacity', np.float64(0.002358433737492945)),
#  ('101_Internal_Resistance', np.float64(0.0023516769853894207)),
#  ('29_Charge_Capacity', np.float64(0.0023157928972087983)),
#  ('6_Internal_Resistance', np.float64(0.002302615855009483)),
#  ('12_Charge_Capacity', np.float64(0.002240773086857894)),
#  ('91_Charge_Capacity', np.float64(0.002215202703136128)),
#  ('100_Charge_Capacity', np.float64(0.002215196097865284)),
#  ('95_Charge_Capacity', np.float64(0.002199929367492324)),
#  ('94_Charge_Capacity', np.float64(0.0021806879969470286)),
#  ('31_Charge_Capacity', np.float64(0.002175825101190631)),
#  ('89_Charge_Capacity', np.float64(0.0021548643951054395)),
#  ('9_Internal_Resistance', np.float64(0.0021468396881813004)),
#  ('22_Charge_Capacity', np.float64(0.002143128677567896)),
#  ('99_Charge_Capacity', np.float64(0.0021305353309328517)),
#  ('10_Internal_Resistance', np.float64(0.0021189984241724957)),
#  ('88_Charge_Capacity', np.float64(0.0021076063442044962)),
#  ('28_Charge_Capacity', np.float64(0.0021049614410540655)),
#  ('93_Charge_Capacity', np.float64(0.0020857859346989035)),
#  ('46_Charge_Capacity', np.float64(0.002069730468047292)),
#  ('7_Internal_Resistance', np.float64(0.0020512833102314778)),
#  ('90_Internal_Resistance', np.float64(0.002046464874634805)),
#  ('59_Charge_Capacity', np.float64(0.002035370715578794)),
#  ('82_Internal_Resistance', np.float64(0.002022409569648566)),
#  ('82_Charge_Capacity', np.float64(0.001991635354675724)),
#  ('71_Charge_Capacity', np.float64(0.001962905482036473)),
#  ('86_Charge_Capacity', np.float64(0.0019578340473390137)),
#  ('75_Internal_Resistance', np.float64(0.0019562142825789858)),
#  ('80_Internal_Resistance', np.float64(0.001921539288667085)),
#  ('81_Internal_Resistance', np.float64(0.0018981100664472047)),
#  ('84_Internal_Resistance', np.float64(0.0018892205668744819)),
#  ('19_Charge_Capacity', np.float64(0.001876546317996107)),
#  ('74_Internal_Resistance', np.float64(0.0018750119444850464)),
#  ('101_Charge_Capacity', np.float64(0.0018563717023198103)),
#  ('68_Internal_Resistance', np.float64(0.0018454084347095945)),
#  ('85_Internal_Resistance', np.float64(0.001841109408252511)),
#  ('80_Charge_Capacity', np.float64(0.001838461148941557)),
#  ('85_Charge_Capacity', np.float64(0.0018244261858355933)),
#  ('83_Internal_Resistance', np.float64(0.0018158608493460116)),
#  ('26_Charge_Capacity', np.float64(0.0018095107891798188)),
#  ('27_Charge_Capacity', np.float64(0.0017848110109568154)),
#  ('71_Internal_Resistance', np.float64(0.0017676208682327777)),
#  ('8_Internal_Resistance', np.float64(0.0017563354679605706)),
#  ('83_Charge_Capacity', np.float64(0.0017556948378892826)),
#  ('51_Charge_Capacity', np.float64(0.0017548769757313454)),
#  ('79_Charge_Capacity', np.float64(0.0017474432666641593)),
#  ('10_Charge_Capacity', np.float64(0.0017105054918553472)),
#  ('20_Charge_Capacity', np.float64(0.001699366617254524)),
#  ('67_Internal_Resistance', np.float64(0.0016772765711211295)),
#  ('45_Charge_Capacity', np.float64(0.001672096671243003)),
#  ('79_Internal_Resistance', np.float64(0.001658937364072193)),
#  ('72_Internal_Resistance', np.float64(0.0016325164759249367)),
#  ('69_Internal_Resistance', np.float64(0.001617748957519731)),
#  ('73_Internal_Resistance', np.float64(0.0016151051548458123)),
#  ('17_Charge_Capacity', np.float64(0.0016097484997536042)),
#  ('89_Internal_Resistance', np.float64(0.0016092916203472802)),
#  ('70_Internal_Resistance', np.float64(0.001589235086281077)),
#  ('87_Internal_Resistance', np.float64(0.0015687189330066014)),
#  ('78_Internal_Resistance', np.float64(0.0015632945459824244)),
#  ('86_Internal_Resistance', np.float64(0.0015478491909049318)),
#  ('21_Charge_Capacity', np.float64(0.0015467189590770663)),
#  ('33_Charge_Capacity', np.float64(0.0015451935284237486)),
#  ('38_Charge_Capacity', np.float64(0.001524412794121585)),
#  ('26_Internal_Resistance', np.float64(0.0015125892144083025)),
#  ('47_Charge_Capacity', np.float64(0.0015044052734880546)),
#  ('11_Internal_Resistance', np.float64(0.0015018306681314822)),
#  ('15_Internal_Resistance', np.float64(0.0015016439932065194)),
#  ('77_Internal_Resistance', np.float64(0.0014967075802252458)),
#  ('68_Charge_Capacity', np.float64(0.0014938913184731498)),
#  ('78_Charge_Capacity', np.float64(0.0014778464254618566)),
#  ('76_Internal_Resistance', np.float64(0.0014727785993514392)),
#  ('17_Internal_Resistance', np.float64(0.0014715303334372279)),
#  ('25_Charge_Capacity', np.float64(0.0014703746149833238)),
#  ('34_Charge_Capacity', np.float64(0.0014690743906010516)),
#  ('12_Internal_Resistance', np.float64(0.001468869426175968)),
#  ('81_Charge_Capacity', np.float64(0.0014630864989335574)),
#  ('60_Charge_Capacity', np.float64(0.0014605708461484692)),
#  ('66_Internal_Resistance', np.float64(0.001453112539276538)),
#  ('52_Internal_Resistance', np.float64(0.0014503829885233895)),
#  ('9_Charge_Capacity', np.float64(0.0014354878479443044)),
#  ('25_Internal_Resistance', np.float64(0.001432311419069725)),
#  ('16_Temperature', np.float64(0.0014321278393586245)),
#  ('14_Internal_Resistance', np.float64(0.001431797332717453)),
#  ('13_Internal_Resistance', np.float64(0.001422256786310865)),
#  ('35_Charge_Capacity', np.float64(0.0014091253618092338)),
#  ('7_Charge_Capacity', np.float64(0.0013971090537077565)),
#  ('16_Internal_Resistance', np.float64(0.0013923863094924328)),
#  ('24_Internal_Resistance', np.float64(0.001391781739031398)),
#  ('36_Charge_Capacity', np.float64(0.0013744287761141072)),
#  ('77_Charge_Capacity', np.float64(0.0013742130787659883)),
#  ('23_Internal_Resistance', np.float64(0.0013697048173111355)),
#  ('18_Internal_Resistance', np.float64(0.0013467516876219047)),
#  ('55_Charge_Capacity', np.float64(0.0013460374016943683)),
#  ('88_Internal_Resistance', np.float64(0.0013410711459895426)),
#  ('54_Charge_Capacity', np.float64(0.0013397400451224245)),
#  ('43_Charge_Capacity', np.float64(0.0013368889108044295)),
#  ('32_Charge_Capacity', np.float64(0.0013334512816860736)),
#  ('63_Charge_Capacity', np.float64(0.0013267746094677495)),
#  ('51_Internal_Resistance', np.float64(0.0012937036251071251)),
#  ('75_Charge_Capacity', np.float64(0.001291519747351698)),
#  ('60_Temperature', np.float64(0.0012590417082757965)),
#  ('84_Charge_Capacity', np.float64(0.001230980243476901)),
#  ('48_Charge_Capacity', np.float64(0.0012281701566640298)),
#  ('21_Internal_Resistance', np.float64(0.0012272727191540047)),
#  ('53_Charge_Capacity', np.float64(0.001226827105847134)),
#  ('8_Charge_Capacity', np.float64(0.0012185081816949396)),
#  ('76_Charge_Capacity', np.float64(0.0012139446848660818)),
#  ('49_Charge_Capacity', np.float64(0.0012126490999185935)),
#  ('84_Temperature', np.float64(0.0012121926340152832)),
#  ('74_Charge_Capacity', np.float64(0.0011861219413032797)),
#  ('70_Charge_Capacity', np.float64(0.001185801318011032)),
#  ('20_Internal_Resistance', np.float64(0.0011622480607016582)),
#  ('85_Temperature', np.float64(0.001124672738276074)),
#  ('50_Internal_Resistance', np.float64(0.0011242475368382046)),
#  ('40_Charge_Capacity', np.float64(0.0011241120413162334)),
#  ('87_Temperature', np.float64(0.0011228464215366847)),
#  ('56_Charge_Capacity', np.float64(0.001121295725128639)),
#  ('47_Internal_Resistance', np.float64(0.00110556194920839)),
#  ('33_Internal_Resistance', np.float64(0.0010998250598446536)),
#  ('72_Charge_Capacity', np.float64(0.0010939648983483868)),
#  ('60_Internal_Resistance', np.float64(0.0010936622959159584)),
#  ('62_Temperature', np.float64(0.0010916833269440183)),
#  ('28_Internal_Resistance', np.float64(0.0010863691361093462)),
#  ('73_Charge_Capacity', np.float64(0.001082993693139924)),
#  ('39_Charge_Capacity', np.float64(0.0010764569628773366)),
#  ('49_Internal_Resistance', np.float64(0.0010760081564486386)),
#  ('22_Internal_Resistance', np.float64(0.001074920884460947)),
#  ('65_Internal_Resistance', np.float64(0.001073178186590775)),
#  ('79_Temperature', np.float64(0.0010714680599457618)),
#  ('63_Internal_Resistance', np.float64(0.0010647972980588822)),
#  ('69_Charge_Capacity', np.float64(0.001062006592875611)),
#  ('19_Internal_Resistance', np.float64(0.001061481969487932)),
#  ('67_Charge_Capacity', np.float64(0.001057909877171407)),
#  ('45_Internal_Resistance', np.float64(0.0010578625117911168)),
#  ('44_Internal_Resistance', np.float64(0.0010572059584282433)),
#  ('65_Charge_Capacity', np.float64(0.0010571335054949406)),
#  ('88_Temperature', np.float64(0.0010571245284527603)),
#  ('54_Internal_Resistance', np.float64(0.0010434420624785136)),
#  ('53_Internal_Resistance', np.float64(0.001043329345234116)),
#  ('102_Temperature', np.float64(0.001042669993184009)),
#  ('83_Temperature', np.float64(0.0010401325121185535)),
#  ('62_Internal_Resistance', np.float64(0.001036250339727631)),
#  ('27_Internal_Resistance', np.float64(0.001031798180727212)),
#  ('61_Internal_Resistance', np.float64(0.001031381940340498)),
#  ('64_Charge_Capacity', np.float64(0.001028782232870377)),
#  ('41_Charge_Capacity', np.float64(0.0010270600864142959)),
#  ('64_Internal_Resistance', np.float64(0.0010269289580698926)),
#  ('34_Internal_Resistance', np.float64(0.001022542010193769)),
#  ('24_Temperature', np.float64(0.0010176034537218582)),
#  ('86_Temperature', np.float64(0.0010146599589569384)),
#  ('29_Internal_Resistance', np.float64(0.0010134085633218585)),
#  ('30_Internal_Resistance', np.float64(0.0010030071797408912)),
#  ('24_Charge_Capacity', np.float64(0.0010020940335555323)),
#  ('38_Internal_Resistance', np.float64(0.0010005365443779349)),
#  ('61_Temperature', np.float64(0.0010001384585298684)),
#  ('32_Internal_Resistance', np.float64(0.0009967995134517996)),
#  ('73_Temperature', np.float64(0.000992528507304975)),
#  ('92_Temperature', np.float64(0.0009856825852555089)),
#  ('48_Internal_Resistance', np.float64(0.000983357926649001)),
#  ('50_Charge_Capacity', np.float64(0.0009799217916512217)),
#  ('90_Temperature', np.float64(0.0009775744897519351)),
#  ('42_Charge_Capacity', np.float64(0.0009761305953436997)),
#  ('27_Temperature', np.float64(0.0009718092969997887)),
#  ('66_Charge_Capacity', np.float64(0.0009685354671806341)),
#  ('23_Charge_Capacity', np.float64(0.0009667605080521908)),
#  ('35_Internal_Resistance', np.float64(0.0009652647795941274)),
#  ('23_Temperature', np.float64(0.0009639242712288157)),
#  ('33_Temperature', np.float64(0.0009607684821447297)),
#  ('46_Internal_Resistance', np.float64(0.0009605749373055122)),
#  ('59_Temperature', np.float64(0.0009595960512291895)),
#  ('77_Temperature', np.float64(0.000954167351845427)),
#  ('25_Temperature', np.float64(0.0009539435998298732)),
#  ('37_Internal_Resistance', np.float64(0.0009489413962403554)),
#  ('41_Internal_Resistance', np.float64(0.0009480541586110733)),
#  ('36_Internal_Resistance', np.float64(0.0009469854862195342)),
#  ('55_Temperature', np.float64(0.000945927819348362)),
#  ('31_Internal_Resistance', np.float64(0.0009449150291278525)),
#  ('57_Temperature', np.float64(0.0009410610229074413)),
#  ('22_Temperature', np.float64(0.0009396300449329418)),
#  ('74_Temperature', np.float64(0.0009391498760621772)),
#  ('78_Temperature', np.float64(0.0009382979729762409)),
#  ('58_Temperature', np.float64(0.0009313939845343927)),
#  ('91_Temperature', np.float64(0.0009273598282161464)),
#  ('59_Internal_Resistance', np.float64(0.0009266080033034539)),
#  ('56_Temperature', np.float64(0.0009261157002791178)),
#  ('28_Temperature', np.float64(0.0009236288826589514)),
#  ('26_Temperature', np.float64(0.0009210110109403668)),
#  ('70_Temperature', np.float64(0.0009195556003944113)),
#  ('62_Charge_Capacity', np.float64(0.0009183634220573881)),
#  ('39_Internal_Resistance', np.float64(0.0009157529002259069)),
#  ('72_Temperature', np.float64(0.0009113307145286461)),
#  ('35_Temperature', np.float64(0.0009102093480451591)),
#  ('56_Internal_Resistance', np.float64(0.0009056714029371526)),
#  ('13_Temperature', np.float64(0.000897086533007209)),
#  ('21_Temperature', np.float64(0.0008962603785923497)),
#  ('80_Temperature', np.float64(0.0008928153216808706)),
#  ('96_Temperature', np.float64(0.0008902073018302944)),
#  ('50_Temperature', np.float64(0.0008841792242260835)),
#  ('58_Internal_Resistance', np.float64(0.0008838967943838099)),
#  ('40_Internal_Resistance', np.float64(0.0008835667983069875)),
#  ('19_Temperature', np.float64(0.0008830894577195657)),
#  ('81_Temperature', np.float64(0.0008763108584990428)),
#  ('42_Temperature', np.float64(0.00087120000889664)),
#  ('101_Temperature', np.float64(0.0008670880408217113)),
#  ('95_Temperature', np.float64(0.0008636467761952869)),
#  ('94_Temperature', np.float64(0.0008635534664234843)),
#  ('99_Temperature', np.float64(0.0008631973455954066)),
#  ('89_Temperature', np.float64(0.0008590384852555296)),
#  ('18_Temperature', np.float64(0.0008557746343003042)),
#  ('100_Temperature', np.float64(0.0008552849684227689)),
#  ('51_Temperature', np.float64(0.0008539084915154879)),
#  ('97_Temperature', np.float64(0.0008455199857856638)),
#  ('57_Internal_Resistance', np.float64(0.000840110628060231)),
#  ('42_Internal_Resistance', np.float64(0.0008392012447636074)),
#  ('55_Internal_Resistance', np.float64(0.0008379086053074736)),
#  ('103_Temperature', np.float64(0.0008353803751984814)),
#  ('93_Temperature', np.float64(0.0008347506753375488)),
#  ('67_Temperature', np.float64(0.0008270918931349814)),
#  ('65_Temperature', np.float64(0.0008251233444657175)),
#  ('71_Temperature', np.float64(0.0008180320028223177)),
#  ('48_Temperature', np.float64(0.0008169078729451805)),
#  ('11_Temperature', np.float64(0.0008168784073646923)),
#  ('43_Internal_Resistance', np.float64(0.0008147929148774771)),
#  ('61_Charge_Capacity', np.float64(0.0008145955324386085)),
#  ('82_Temperature', np.float64(0.0008058446934493913)),
#  ('31_Temperature', np.float64(0.0008052553368657764)),
#  ('69_Temperature', np.float64(0.0008028606099270107)),
#  ('40_Temperature', np.float64(0.0008006964492904036)),
#  ('47_Temperature', np.float64(0.0007922447671974736)),
#  ('29_Temperature', np.float64(0.0007916789146160231)),
#  ('44_Temperature', np.float64(0.0007846701808579675)),
#  ('30_Temperature', np.float64(0.0007826981798697202)),
#  ('98_Temperature', np.float64(0.0007793046328812396)),
#  ('14_Temperature', np.float64(0.0007791561775183595)),
#  ('15_Temperature', np.float64(0.0007789921340085337)),
#  ('68_Temperature', np.float64(0.0007783604694709749)),
#  ('75_Temperature', np.float64(0.0007777750113870508)),
#  ('20_Temperature', np.float64(0.0007768526777488606)),
#  ('12_Temperature', np.float64(0.000775877457873144)),
#  ('32_Temperature', np.float64(0.0007749596745902991)),
#  ('34_Temperature', np.float64(0.0007711389190980738)),
#  ('66_Temperature', np.float64(0.0007702629610209326)),
#  ('41_Temperature', np.float64(0.0007641812466009429)),
#  ('64_Temperature', np.float64(0.0007623337322360147)),
#  ('38_Temperature', np.float64(0.000760011070872206)),
#  ('63_Temperature', np.float64(0.0007599765224352676)),
#  ('37_Temperature', np.float64(0.0007575232399157792)),
#  ('49_Temperature', np.float64(0.0007573831030648705)),
#  ('36_Temperature', np.float64(0.0007527735820063006)),
#  ('43_Temperature', np.float64(0.0007503973766215689)),
#  ('53_Temperature', np.float64(0.000746060246849985)),
#  ('39_Temperature', np.float64(0.0007414662974059793)),
#  ('10_Temperature', np.float64(0.0007309347331730813)),
#  ('8_Temperature', np.float64(0.0007183799858908256)),
#  ('17_Temperature', np.float64(0.0007181636249420576)),
#  ('45_Temperature', np.float64(0.0007143493169041827)),
#  ('6_Temperature', np.float64(0.0006966506900546245)),
#  ('54_Temperature', np.float64(0.0006878699391247882)),
#  ('9_Temperature', np.float64(0.0006817454888975912)),
#  ('52_Temperature', np.float64(0.0006807455601004666)),
#  ('7_Temperature', np.float64(0.0006801451448848135)),
#  ('5_Temperature', np.float64(0.000669169037829342)),
#  ('76_Temperature', np.float64(0.0006639707829203932)),
#  ('4_Temperature', np.float64(0.0006567071285139955)),
#  ('46_Temperature', np.float64(0.0006366482756283206)),
#  ('schedule_version', np.float64(0.00033952690465879497)),
#  ('2_Charge_Capacity', np.float64(0.0))]
